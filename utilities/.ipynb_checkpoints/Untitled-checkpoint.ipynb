# %%
import os
import matplotlib
import seaborn as sns
import lxml
from bs4 import BeautifulSoup
import glob
import pandas as pd

# %% [markdown]
# # Problem Space

# %%
with open("../figures/feature_ide/problem/model.xml") as f:
    xml = f.read()

# %%
soup=BeautifulSoup(xml,"xml")

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <featureModel chosenLayoutAlgorithm="0">
#  <struct>
#   <and abstract="true" coordinates="690, -85" mandatory="true" name="Application">
#    <or abstract="true" coordinates="190, 130" name="InteractiveVisualization">
#     <and coordinates="58, 201" mandatory="true" name="SpatialVis">
#      <or abstract="true" coordinates="-45, 251" mandatory="true" name="Dimensions">
#       <feature coordinates="-50, 301" mandatory="true" name="Two"/>
#       <feature coordinates="-12, 301" mandatory="true" name="Three"/>
#      </or>
#      <or abstract="true" coordinates="120, 251" mandatory="true" name="GeometricObjects">
#       <feature coordinates="34, 301" mandatory="true" name="Images"/>
#       <feature coordinates="86, 301" mandatory="true" name="Surfaces"/>
#       <feature coordinates="147, 301" mandatory="true" name="Tractography"/>
#       <feature coordinates="230, 301" mandatory="true" name="Segmentation"/>
#      </or>
#     </and>
#     <or coordinates="467, 245" mandatory="true" name="NonSpatialVis">
#      <feature coordinates="311, 301" mandatory="true" name="Bars"/>
#      <feature coordinates="351, 301" mandatory="true" name="Scatter"/>
#      <feature coordinates="403, 301" mandatory="true" name="Histogram"/>
#      <feature coordinates="469, 301" mandatory="true" name="BoxPlot"/>
#      <feature coordinates="523, 301" mandatory="true" name="Spider"/>
#      <feature coordinates="571, 301" mandatory="true" name="TimeLine"/>
#      <feature coordinates="631, 301" mandatory="true" name="ParallelCoordinates"/>
#     </or>
#    </or>
#    <or abstract="true" coordinates="577, 18" name="Workflow">
#     <feature coordinates="502, 68" mandatory="true" name="SaveRestore"/>
#     <feature coordinates="583, 68" mandatory="true" name="Log"/>
#     <and abstract="true" coordinates="618, 68" mandatory="true" name="Communications">
#      <or abstract="true" coordinates="553, 117" name="Send">
#       <feature coordinates="402, 167" mandatory="true" name="SendSample"/>
#       <feature coordinates="479, 167" mandatory="true" name="SendSubject"/>
#       <feature coordinates="557, 167" mandatory="true" name="SendVisualization"/>
#       <feature coordinates="662, 167" mandatory="true" name="SendVariables"/>
#      </or>
#      <or abstract="true" coordinates="766, 170" name="Receive">
#       <feature coordinates="593, 220" mandatory="true" name="ReceiveSample"/>
#       <feature coordinates="685, 220" mandatory="true" name="ReceiveSubject"/>
#       <feature coordinates="778, 220" mandatory="true" name="ReceiveVisualization"/>
#       <feature coordinates="895, 220" mandatory="true" name="ReceiveVariables"/>
#      </or>
#     </and>
#    </or>
#    <alt abstract="true" coordinates="782, 31" name="Interface">
#     <feature coordinates="745, 78" mandatory="true" name="Graphical"/>
#     <feature coordinates="806, 78" mandatory="true" name="CommandLine"/>
#    </alt>
#    <or abstract="true" coordinates="982, 26" name="Processing">
#     <or abstract="true" coordinates="928, 89" mandatory="true" name="ManualAssist">
#      <feature coordinates="826, 169" mandatory="true" name="DefineRegions"/>
#      <feature coordinates="914, 169" mandatory="true" name="ManualMeasure"/>
#      <feature coordinates="1009, 169" mandatory="true" name="ManualSegmentation"/>
#     </or>
#     <or abstract="true" coordinates="1129, 177" mandatory="true" name="Automatic">
#      <or abstract="true" coordinates="1002, 254" mandatory="true" name="GeometricalProc">
#       <feature coordinates="963, 297" mandatory="true" name="Filter"/>
#       <feature coordinates="1005, 298" mandatory="true" name="Isosurfaces"/>
#       <feature coordinates="1080, 298" mandatory="true" name="Transform"/>
#      </or>
#      <or abstract="true" coordinates="1263, 248" mandatory="true" name="StatisticalProc">
#       <feature coordinates="1147, 298" mandatory="true" name="LinearModels"/>
#       <feature coordinates="1229, 298" mandatory="true" name="Classification"/>
#       <feature coordinates="1310, 298" mandatory="true" name="Clustering"/>
#       <feature coordinates="1376, 298" mandatory="true" name="NonParametric"/>
#      </or>
#     </or>
#    </or>
#   </and>
#  </struct>
#  <constraints>
#   <rule coordinates="670, 349">
#    <imp>
#     <var>
#      InteractiveVisualization
#     </var>
#     <var>
#      Graphical
#     </var>
#    </imp>
#   </rule>
#   <rule coordinates="687, 363">
#    <imp>
#     <var>
#      ManualAssist
#     </var>
#     <var>
#      SpatialVis
#     </var>
#    </imp>
#   </rule>
#  </constraints>
#  <calculations Auto="true" Constraints="true" Features="true" Redundant="true" Tautology="true"/>
#  <comments/>
#  <featureOrder userDefined="false"/>
# </featureModel>

# %%
model = soup.struct

# %%
features = model.findAll(["and","or","feature"])

# %%
# Remove abstract
features = [ f for f in features if not f.has_attr("abstract")]

# %%
feature_names = [f["name"] for f in features]

# %%
feature_names
# Out:
# ['SpatialVis',
#  'Two',
#  'Three',
#  'Images',
#  'Surfaces',
#  'Tractography',
#  'Segmentation',
#  'NonSpatialVis',
#  'Bars',
#  'Scatter',
#  'Histogram',
#  'BoxPlot',
#  'Spider',
#  'TimeLine',
#  'ParallelCoordinates',
#  'SaveRestore',
#  'Log',
#  'SendSample',
#  'SendSubject',
#  'SendVisualization',
#  'SendVariables',
#  'ReceiveSample',
#  'ReceiveSubject',
#  'ReceiveVisualization',
#  'ReceiveVariables',
#  'Graphical',
#  'CommandLine',
#  'DefineRegions',
#  'ManualMeasure',
#  'ManualSegmentation',
#  'Filter',
#  'Isosurfaces',
#  'Transform',
#  'LinearModels',
#  'Classification',
#  'Clustering',
#  'NonParametric']

# %%
apps_cfgs = glob.glob("../figures/feature_ide/problem/configs/*.config")
# remove default
apps_cfgs=[a for a in apps_cfgs if not a.endswith("default.config")]

# %%
def get_features(cfg_file):
    with open(cfg_file) as f:
        lines = f.readlines()
    active_features={l.strip() for l in lines}
    features = {f:f in active_features for f in feature_names }
    return features

# %%
all_features = {c[:-7].split("/")[-1]:get_features(c) for c in apps_cfgs}

# %%
all_features
# Out:
# {'Anova': {'Bars': False,
#   'BoxPlot': True,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': True,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': True,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'CalculateFeatures': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': True,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': False,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False},
#  'CheckRegistration': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False},
#  'Correlations': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': True,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': True,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'ExploreFMRI': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': True,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False},
#  'Histogram': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': True,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'LinearMeasure': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': True,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False},
#  'LinearModel': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': True,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': True,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'LogicBundles': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': True,
#   'Two': False},
#  'ParallelCoordinates': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': True,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': True,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'PopulateCache': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': True,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': False,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False},
#  'RoiBuilder': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': True,
#   'Filter': True,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': False,
#   'Two': False},
#  'SubjectSwitcher': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False},
#  'sampleOverview': {'Bars': True,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': True,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': True,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': True,
#   'Two': False},
#  'subjOverview': {'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'DefineRegions': False,
#   'Filter': True,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': True,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': True,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': True,
#   'SpatialVis': True,
#   'Spider': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': True,
#   'Two': False}}

# %%
df = pd.DataFrame.from_records(all_features)

# %%
df=df.loc[feature_names]

# %%
df.columns
# Out:
# Index(['Anova', 'CalculateFeatures', 'CheckRegistration', 'Correlations',
#        'ExploreFMRI', 'Histogram', 'LinearMeasure', 'LinearModel',
#        'LogicBundles', 'ParallelCoordinates', 'PopulateCache', 'RoiBuilder',
#        'SubjectSwitcher', 'sampleOverview', 'subjOverview'],
#       dtype='object')

# %%
#Sort columns
df=df[['RoiBuilder', 'LogicBundles', 'LinearMeasure',                 
       'subjOverview', 'sampleOverview', 'ExploreFMRI',        'CheckRegistration',
        'Anova', 'LinearModel', 'Correlations', 'Histogram', 'ParallelCoordinates',  
       'SubjectSwitcher', 'CalculateFeatures','PopulateCache',]]

# %%
df2=df.replace(True,"\checkmark").replace(False,"")
df2.columns=["\\rot{%s}"%c for c in df2.columns]
df2.head()
# Out:
#            \rot{RoiBuilder} \rot{LogicBundles} \rot{LinearMeasure}  \
# SpatialVis       \checkmark         \checkmark          \checkmark
# Two
# Three            \checkmark         \checkmark          \checkmark
# Images           \checkmark         \checkmark          \checkmark
# Surfaces         \checkmark         \checkmark
#
#            \rot{subjOverview} \rot{sampleOverview} \rot{CheckRegistration}  \
# SpatialVis         \checkmark           \checkmark              \checkmark
# Two
# Three              \checkmark           \checkmark              \checkmark
# Images             \checkmark           \checkmark              \checkmark
# Surfaces           \checkmark           \checkmark
#
#            \rot{ExploreFMRI} \rot{Anova} \rot{LinearModel} \rot{Correlations}  \
# SpatialVis        \checkmark
# Two
# Three             \checkmark
# Images            \checkmark
# Surfaces          \checkmark
#
#            \rot{Histogram} \rot{ParallelCoordinates} \rot{SubjectSwitcher}  \
# SpatialVis
# Two
# Three
# Images
# Surfaces
#
#            \rot{CalculateFeatures} \rot{PopulateCache}
# SpatialVis
# Two
# Three
# Images
# Surfaces

# %%
latex_df = df2.to_latex(escape=False,longtable=False)

# %%
with open("../figures/feature_ide/problem/table.tex","w") as f:
    f.write(latex_df)

# %% [markdown]
# # Solution Space

# %%
with open("../figures/feature_ide/solution/model.xml") as f:
    xml = f.read()

# %%
soup=BeautifulSoup(xml,"xml")

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <featureModel chosenLayoutAlgorithm="1">
#  <struct>
#   <and abstract="true" mandatory="true" name="BravizApplication">
#    <alt abstract="true" mandatory="true" name="userInterface">
#     <feature mandatory="true" name="CommandLine"/>
#     <or mandatory="true" name="Web">
#      <feature mandatory="true" name="D3"/>
#      <feature mandatory="true" name="Bootstrap"/>
#      <feature mandatory="true" name="three"/>
#     </or>
#     <or mandatory="true" name="DesktopGUI">
#      <feature mandatory="true" name="MatplotLib"/>
#      <feature mandatory="true" name="VTK"/>
#      <feature mandatory="true" name="QtModels"/>
#      <or mandatory="true" name="ReusableQtComponents">
#       <feature mandatory="true" name="SampleManager"/>
#       <feature mandatory="true" name="ImageManager"/>
#       <feature mandatory="true" name="ContextPanel"/>
#       <feature mandatory="true" name="VariableSelectDialog"/>
#      </or>
#     </or>
#    </alt>
#    <or abstract="true" mandatory="true" name="DataSources">
#     <or abstract="true" mandatory="true" name="Tabular">
#      <feature mandatory="true" name="Variables"/>
#      <feature mandatory="true" name="Samples"/>
#      <feature mandatory="true" name="Annotations"/>
#     </or>
#     <or abstract="true" mandatory="true" name="Spatial">
#      <feature mandatory="true" name="Images"/>
#      <or mandatory="true" name="PolyData">
#       <feature mandatory="true" name="Segmentations"/>
#       <feature mandatory="true" name="Tractography"/>
#       <feature mandatory="true" name="Surfaces"/>
#       <feature mandatory="true" name="Contours"/>
#      </or>
#     </or>
#    </or>
#    <or abstract="true" name="Processing">
#     <or abstract="true" mandatory="true" name="Geometric">
#      <feature mandatory="true" name="VTKFilters"/>
#      <feature mandatory="true" name="Scipy_Numpy"/>
#     </or>
#     <or abstract="true" mandatory="true" name="Statistical">
#      <feature mandatory="true" name="R"/>
#      <feature mandatory="true" name="Scipy"/>
#     </or>
#     <or abstract="true" mandatory="true" name="Manual">
#      <feature mandatory="true" name="SphericalRoi"/>
#      <feature mandatory="true" name="LinearMeasure"/>
#      <feature mandatory="true" name="ManualSegmentation"/>
#     </or>
#    </or>
#    <or abstract="true" name="Workflow">
#     <feature mandatory="true" name="SaveRestore"/>
#     <feature mandatory="true" name="Logging"/>
#     <feature mandatory="true" name="Communications"/>
#    </or>
#   </and>
#  </struct>
#  <constraints>
#   <rule>
#    <imp>
#     <var>
#      Statistical
#     </var>
#     <var>
#      Tabular
#     </var>
#    </imp>
#   </rule>
#   <rule>
#    <imp>
#     <var>
#      Geometric
#     </var>
#     <var>
#      Spatial
#     </var>
#    </imp>
#   </rule>
#   <rule>
#    <imp>
#     <var>
#      SampleManager
#     </var>
#     <var>
#      Samples
#     </var>
#    </imp>
#   </rule>
#  </constraints>
#  <calculations Auto="true" Constraints="true" Features="true" Redundant="true" Tautology="true"/>
#  <comments/>
#  <featureOrder userDefined="false"/>
# </featureModel>

# %%
model = soup.struct

# %%
features = model.findAll(["and","or","feature"])

# %%
# Remove abstract
features = [ f for f in features if not f.has_attr("abstract")]

# %%
feature_names = [f["name"] for f in features]

# %%
feature_names
# Out:
# ['CommandLine',
#  'Web',
#  'D3',
#  'Bootstrap',
#  'three',
#  'DesktopGUI',
#  'MatplotLib',
#  'VTK',
#  'QtModels',
#  'ReusableQtComponents',
#  'SampleManager',
#  'ImageManager',
#  'ContextPanel',
#  'VariableSelectDialog',
#  'Variables',
#  'Samples',
#  'Annotations',
#  'Images',
#  'PolyData',
#  'Segmentations',
#  'Tractography',
#  'Surfaces',
#  'Contours',
#  'VTKFilters',
#  'Scipy_Numpy',
#  'R',
#  'Scipy',
#  'SphericalRoi',
#  'LinearMeasure',
#  'ManualSegmentation',
#  'SaveRestore',
#  'Logging',
#  'Communications']

# %%
apps_cfgs = glob.glob("../figures/feature_ide/solution/configs/*.config")
# remove default
apps_cfgs=[a for a in apps_cfgs if not a.endswith("default.config")]

# %%
def get_features(cfg_file):
    with open(cfg_file) as f:
        lines = f.readlines()
    active_features={l.strip() for l in lines}
    features = {f:f in active_features for f in feature_names }
    return features

# %%
all_features = {c[:-7].split("/")[-1]:get_features(c) for c in apps_cfgs}

# %%
all_features
# Out:
# {'Anova': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': True,
#   'PolyData': False,
#   'QtModels': True,
#   'R': True,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': True,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'CalculateFeatures': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': True,
#   'Communications': False,
#   'ContextPanel': False,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': False,
#   'ImageManager': False,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': False,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': False,
#   'SampleManager': False,
#   'Samples': True,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': True,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': False,
#   'VTKFilters': True,
#   'VariableSelectDialog': False,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'CheckRegistration': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': False,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': False,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': False,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': False,
#   'Samples': False,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': True,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': False,
#   'three': False},
#  'Correlations': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': True,
#   'PolyData': False,
#   'QtModels': True,
#   'R': True,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': True,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'ExploreFMRI': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': True,
#   'PolyData': True,
#   'QtModels': True,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': True,
#   'VTKFilters': True,
#   'VariableSelectDialog': True,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'Histogram': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': True,
#   'DesktopGUI': False,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': False,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': False,
#   'SampleManager': False,
#   'Samples': True,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': True,
#   'Web': True,
#   'three': False},
#  'LinearMeasure': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': True,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': False,
#   'three': False},
#  'LinearModel': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': True,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': True,
#   'PolyData': False,
#   'QtModels': True,
#   'R': True,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': True,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'LogicBundles': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': True,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': True,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': True,
#   'VTKFilters': True,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': False,
#   'three': False},
#  'ParallelCoordinates': {'Annotations': False,
#   'Bootstrap': True,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': True,
#   'DesktopGUI': False,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': False,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': False,
#   'SampleManager': False,
#   'Samples': True,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': True,
#   'Web': True,
#   'three': False},
#  'PopulateCache': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': True,
#   'Communications': False,
#   'ContextPanel': False,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': False,
#   'ImageManager': False,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': False,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': False,
#   'SampleManager': False,
#   'Samples': False,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': False,
#   'three': False},
#  'RoiBuilder': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': False,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': True,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': True,
#   'VTKFilters': True,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': False,
#   'three': False},
#  'SubjectSwitcher': {'Annotations': False,
#   'Bootstrap': True,
#   'CommandLine': False,
#   'Communications': False,
#   'ContextPanel': False,
#   'Contours': False,
#   'D3': False,
#   'DesktopGUI': False,
#   'ImageManager': False,
#   'Images': False,
#   'LinearMeasure': False,
#   'Logging': False,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': False,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': False,
#   'SampleManager': False,
#   'Samples': True,
#   'SaveRestore': False,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': False,
#   'SphericalRoi': False,
#   'Surfaces': False,
#   'Tractography': False,
#   'VTK': False,
#   'VTKFilters': False,
#   'VariableSelectDialog': False,
#   'Variables': False,
#   'Web': True,
#   'three': False},
#  'sampleOverview': {'Annotations': False,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': False,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': True,
#   'PolyData': True,
#   'QtModels': False,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': True,
#   'VTKFilters': False,
#   'VariableSelectDialog': True,
#   'Variables': True,
#   'Web': False,
#   'three': False},
#  'subjOverview': {'Annotations': True,
#   'Bootstrap': False,
#   'CommandLine': False,
#   'Communications': True,
#   'ContextPanel': True,
#   'Contours': True,
#   'D3': False,
#   'DesktopGUI': True,
#   'ImageManager': True,
#   'Images': True,
#   'LinearMeasure': False,
#   'Logging': True,
#   'ManualSegmentation': False,
#   'MatplotLib': False,
#   'PolyData': True,
#   'QtModels': True,
#   'R': False,
#   'ReusableQtComponents': True,
#   'SampleManager': True,
#   'Samples': True,
#   'SaveRestore': True,
#   'Scipy': False,
#   'Scipy_Numpy': False,
#   'Segmentations': True,
#   'SphericalRoi': False,
#   'Surfaces': True,
#   'Tractography': True,
#   'VTK': True,
#   'VTKFilters': True,
#   'VariableSelectDialog': True,
#   'Variables': True,
#   'Web': False,
#   'three': False}}

# %%
df = pd.DataFrame.from_records(all_features)

# %%
df=df.loc[feature_names]

# %%
df.columns
# Out:
# Index(['Anova', 'CalculateFeatures', 'CheckRegistration', 'Correlations',
#        'ExploreFMRI', 'Histogram', 'LinearMeasure', 'LinearModel',
#        'LogicBundles', 'ParallelCoordinates', 'PopulateCache', 'RoiBuilder',
#        'SubjectSwitcher', 'sampleOverview', 'subjOverview'],
#       dtype='object')

# %%
#Sort columns
df=df[['RoiBuilder', 'LogicBundles', 'LinearMeasure',                 
       'subjOverview', 'sampleOverview', 'ExploreFMRI', 'CheckRegistration',       
        'Anova', 'LinearModel','Correlations', 'Histogram', 'ParallelCoordinates',  
       'SubjectSwitcher', 'CalculateFeatures','PopulateCache',]]

# %%
df2=df.replace(True,"\checkmark").replace(False,"")
df2.columns=["\\rot{%s}"%c for c in df2.columns]
df2.head()
# Out:
#             \rot{RoiBuilder} \rot{LogicBundles} \rot{LinearMeasure}  \
# CommandLine
# Web
# D3
# Bootstrap
# three
#
#             \rot{subjOverview} \rot{sampleOverview} \rot{CheckRegistration}  \
# CommandLine
# Web
# D3
# Bootstrap
# three
#
#             \rot{ExploreFMRI} \rot{Anova} \rot{LinearModel}  \
# CommandLine
# Web
# D3
# Bootstrap
# three
#
#             \rot{Correlations} \rot{Histogram} \rot{ParallelCoordinates}  \
# CommandLine
# Web                                 \checkmark                \checkmark
# D3                                  \checkmark                \checkmark
# Bootstrap                                                     \checkmark
# three
#
#             \rot{SubjectSwitcher} \rot{CalculateFeatures} \rot{PopulateCache}
# CommandLine                                    \checkmark          \checkmark
# Web                    \checkmark
# D3
# Bootstrap              \checkmark
# three

# %%
latex_df = df2.to_latex(escape=False,longtable=False)

# %%
with open("../figures/feature_ide/solution/table.tex","w") as f:
    f.write(latex_df)
