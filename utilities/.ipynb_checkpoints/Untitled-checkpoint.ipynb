# %%
import os
import matplotlib
import seaborn as sns
import lxml
from bs4 import BeautifulSoup
import glob
import pandas as pd

# %%
BeautifulSoup?

# %%
with open("../figures/feature_ide/problem/model.xml") as f:
    xml = f.read()

# %%
soup=BeautifulSoup(xml,"xml")

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <featureModel chosenLayoutAlgorithm="0">
#  <struct>
#   <and coordinates="690, -85" mandatory="true" name="Application">
#    <or coordinates="190, 130" name="InteractiveVisualization">
#     <and coordinates="58, 201" mandatory="true" name="SpatialVis">
#      <or abstract="true" coordinates="-45, 251" mandatory="true" name="Dimensions">
#       <feature coordinates="-50, 301" mandatory="true" name="Two"/>
#       <feature coordinates="-12, 301" mandatory="true" name="Three"/>
#      </or>
#      <or abstract="true" coordinates="120, 251" mandatory="true" name="GeometricObjects">
#       <feature coordinates="34, 301" mandatory="true" name="Images"/>
#       <feature coordinates="86, 301" mandatory="true" name="Surfaces"/>
#       <feature coordinates="147, 301" mandatory="true" name="Tractography"/>
#       <feature coordinates="230, 301" mandatory="true" name="Segmentation"/>
#      </or>
#     </and>
#     <or coordinates="467, 245" mandatory="true" name="NonSpatialVis">
#      <feature coordinates="311, 301" mandatory="true" name="Bars"/>
#      <feature coordinates="351, 301" mandatory="true" name="Scatter"/>
#      <feature coordinates="403, 301" mandatory="true" name="Histogram"/>
#      <feature coordinates="469, 301" mandatory="true" name="BoxPlot"/>
#      <feature coordinates="523, 301" mandatory="true" name="Spider"/>
#      <feature coordinates="571, 301" mandatory="true" name="TimeLine"/>
#      <feature coordinates="631, 301" mandatory="true" name="ParallelCoordinates"/>
#     </or>
#    </or>
#    <or coordinates="577, 18" name="Workflow">
#     <feature coordinates="502, 68" mandatory="true" name="SaveRestore"/>
#     <feature coordinates="583, 68" mandatory="true" name="Log"/>
#     <and abstract="true" coordinates="618, 68" mandatory="true" name="Communications">
#      <or abstract="true" coordinates="553, 117" name="Send">
#       <feature coordinates="402, 167" mandatory="true" name="SendSample"/>
#       <feature coordinates="479, 167" mandatory="true" name="SendSubject"/>
#       <feature coordinates="557, 167" mandatory="true" name="SendVisualization"/>
#       <feature coordinates="662, 167" mandatory="true" name="SendVariables"/>
#      </or>
#      <or abstract="true" coordinates="766, 170" name="Receive">
#       <feature coordinates="593, 220" mandatory="true" name="ReceiveSample"/>
#       <feature coordinates="685, 220" mandatory="true" name="ReceiveSubject"/>
#       <feature coordinates="778, 220" mandatory="true" name="ReceiveVisualization"/>
#       <feature coordinates="895, 220" mandatory="true" name="ReceiveVariables"/>
#      </or>
#     </and>
#    </or>
#    <alt abstract="true" coordinates="782, 31" name="Interface">
#     <feature coordinates="745, 78" mandatory="true" name="Graphical"/>
#     <feature coordinates="806, 78" mandatory="true" name="CommandLine"/>
#    </alt>
#    <or coordinates="982, 26" name="Processing">
#     <or abstract="true" coordinates="928, 89" mandatory="true" name="ManualAssist">
#      <feature coordinates="826, 169" mandatory="true" name="DefineRegions"/>
#      <feature coordinates="914, 169" mandatory="true" name="ManualMeasure"/>
#      <feature coordinates="1009, 169" mandatory="true" name="ManualSegmentation"/>
#     </or>
#     <or abstract="true" coordinates="1129, 177" mandatory="true" name="Automatic">
#      <or abstract="true" coordinates="1002, 254" mandatory="true" name="GeometricalProc">
#       <feature coordinates="887, 298" mandatory="true" name="Filter"/>
#       <feature coordinates="928, 298" mandatory="true" name="Reconstruct"/>
#       <feature coordinates="1005, 298" mandatory="true" name="Isosurfaces"/>
#       <feature coordinates="1080, 298" mandatory="true" name="Transform"/>
#      </or>
#      <or abstract="true" coordinates="1263, 248" mandatory="true" name="StatisticalProc">
#       <feature coordinates="1147, 298" mandatory="true" name="LinearModels"/>
#       <feature coordinates="1229, 298" mandatory="true" name="Classification"/>
#       <feature coordinates="1310, 298" mandatory="true" name="Clustering"/>
#       <feature coordinates="1376, 298" mandatory="true" name="NonParametric"/>
#      </or>
#     </or>
#    </or>
#   </and>
#  </struct>
#  <constraints>
#   <rule coordinates="670, 349">
#    <imp>
#     <var>
#      InteractiveVisualization
#     </var>
#     <var>
#      Graphical
#     </var>
#    </imp>
#   </rule>
#   <rule coordinates="687, 363">
#    <imp>
#     <var>
#      ManualAssist
#     </var>
#     <var>
#      SpatialVis
#     </var>
#    </imp>
#   </rule>
#  </constraints>
#  <calculations Auto="true" Constraints="true" Features="true" Redundant="true" Tautology="true"/>
#  <comments/>
#  <featureOrder userDefined="false"/>
# </featureModel>

# %%
model = soup.struct

# %%
features = model.findAll(["and","or","feature"])

# %%
feature_names = [f["name"] for f in features]

# %%
feature_names
# Out:
# ['Application',
#  'InteractiveVisualization',
#  'SpatialVis',
#  'Dimensions',
#  'Two',
#  'Three',
#  'GeometricObjects',
#  'Images',
#  'Surfaces',
#  'Tractography',
#  'Segmentation',
#  'NonSpatialVis',
#  'Bars',
#  'Scatter',
#  'Histogram',
#  'BoxPlot',
#  'Spider',
#  'TimeLine',
#  'ParallelCoordinates',
#  'Workflow',
#  'SaveRestore',
#  'Log',
#  'Communications',
#  'Send',
#  'SendSample',
#  'SendSubject',
#  'SendVisualization',
#  'SendVariables',
#  'Receive',
#  'ReceiveSample',
#  'ReceiveSubject',
#  'ReceiveVisualization',
#  'ReceiveVariables',
#  'Graphical',
#  'CommandLine',
#  'Processing',
#  'ManualAssist',
#  'DefineRegions',
#  'ManualMeasure',
#  'ManualSegmentation',
#  'Automatic',
#  'GeometricalProc',
#  'Filter',
#  'Reconstruct',
#  'Isosurfaces',
#  'Transform',
#  'StatisticalProc',
#  'LinearModels',
#  'Classification',
#  'Clustering',
#  'NonParametric']

# %%
feature_names=feature_names[1:]  # Remove abstract

# %%
apps_cfgs = glob.glob("../figures/feature_ide/problem/configs/*.config")

# %%
def get_features(cfg_file):
    with open(cfg_file) as f:
        lines = f.readlines()
    active_features={l.strip() for l in lines}
    features = {f:f in active_features for f in feature_names }
    return features

# %%
all_features = {c[:-7].split("/")[-1]:get_features(c) for c in apps_cfgs}

# %%
all_features
# Out:
# {'Anva': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': True,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': True,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'CalculateFeatures': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': True,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': False,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': False,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': True,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False,
#   'Workflow': False},
#  'CheckRegistration': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False,
#   'Workflow': False},
#  'Correlations': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': True,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'ExploreFMRI': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': True,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': True,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False,
#   'Workflow': True},
#  'Histogram': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': True,
#   'Images': False,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': False,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'LinearMeasure': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': True,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False,
#   'Workflow': True},
#  'LinearModel': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': True,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': True,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': False},
#  'LogicBundles': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': True,
#   'Two': False,
#   'Workflow': True},
#  'ParallelCoordinates': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': True,
#   'Processing': False,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'PopulateCache': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': True,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': False,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': False,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': True,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': True,
#   'Two': False,
#   'Workflow': False},
#  'RoiBuilder': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': True,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': False,
#   'ReceiveSubject': False,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': False,
#   'SendSubject': False,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'SubjectSwitcher': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': False,
#   'InteractiveVisualization': False,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': False,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': False,
#   'Scatter': False,
#   'Segmentation': False,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': False,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': False,
#   'Three': False,
#   'TimeLine': False,
#   'Tractography': False,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'default': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': False,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': True,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'sampleOverview': {'Automatic': False,
#   'Bars': True,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': False,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': False,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': True,
#   'ParallelCoordinates': False,
#   'Processing': False,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': False,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': True,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': False,
#   'Two': False,
#   'Workflow': True},
#  'subjOverview': {'Automatic': False,
#   'Bars': False,
#   'BoxPlot': False,
#   'Classification': False,
#   'Clustering': False,
#   'CommandLine': False,
#   'Communications': False,
#   'DefineRegions': False,
#   'Dimensions': False,
#   'Filter': True,
#   'GeometricObjects': False,
#   'GeometricalProc': False,
#   'Graphical': True,
#   'Histogram': False,
#   'Images': True,
#   'InteractiveVisualization': True,
#   'Isosurfaces': True,
#   'LinearModels': False,
#   'Log': True,
#   'ManualAssist': False,
#   'ManualMeasure': False,
#   'ManualSegmentation': False,
#   'NonParametric': False,
#   'NonSpatialVis': False,
#   'ParallelCoordinates': False,
#   'Processing': True,
#   'Receive': False,
#   'ReceiveSample': True,
#   'ReceiveSubject': True,
#   'ReceiveVariables': False,
#   'ReceiveVisualization': False,
#   'Reconstruct': True,
#   'SaveRestore': True,
#   'Scatter': False,
#   'Segmentation': True,
#   'Send': False,
#   'SendSample': True,
#   'SendSubject': True,
#   'SendVariables': False,
#   'SendVisualization': False,
#   'SpatialVis': True,
#   'Spider': False,
#   'StatisticalProc': False,
#   'Surfaces': True,
#   'Three': True,
#   'TimeLine': False,
#   'Tractography': True,
#   'Transform': True,
#   'Two': False,
#   'Workflow': True}}

# %%
df = pd.DataFrame.from_records(all_features)

# %%
df=df.loc[feature_names]

# %%
df2=df.replace(True,"\checkmark").replace(False,"")
df2.columns=["\\rot{%s}"%c for c in df2.columns]
df2.head()
# Out:
#                           \rot{Anva} \rot{CalculateFeatures}  \
# InteractiveVisualization  \checkmark
# SpatialVis
# Dimensions
# Two
# Three
#
#                          \rot{CheckRegistration} \rot{Correlations}  \
# InteractiveVisualization              \checkmark         \checkmark
# SpatialVis                            \checkmark
# Dimensions
# Two
# Three                                 \checkmark
#
#                          \rot{ExploreFMRI} \rot{Histogram}  \
# InteractiveVisualization        \checkmark      \checkmark
# SpatialVis                      \checkmark
# Dimensions
# Two
# Three                           \checkmark
#
#                          \rot{LinearMeasure} \rot{LinearModel}  \
# InteractiveVisualization          \checkmark        \checkmark
# SpatialVis                        \checkmark
# Dimensions
# Two
# Three                             \checkmark
#
#                          \rot{LogicBundles} \rot{ParallelCoordinates}  \
# InteractiveVisualization         \checkmark                \checkmark
# SpatialVis                       \checkmark
# Dimensions
# Two
# Three                            \checkmark
#
#                          \rot{PopulateCache} \rot{RoiBuilder}  \
# InteractiveVisualization                           \checkmark
# SpatialVis                                         \checkmark
# Dimensions
# Two
# Three                                              \checkmark
#
#                          \rot{SubjectSwitcher} \rot{default}  \
# InteractiveVisualization                          \checkmark
# SpatialVis                                        \checkmark
# Dimensions
# Two
# Three                                             \checkmark
#
#                          \rot{sampleOverview} \rot{subjOverview}
# InteractiveVisualization           \checkmark         \checkmark
# SpatialVis                         \checkmark         \checkmark
# Dimensions
# Two
# Three                              \checkmark         \checkmark

# %%
latex_df = df2.to_latex(escape=False,longtable=False)

# %%
with open("../figures/feature_ide/problem/table.tex","w") as f:
    f.write(latex_df)
